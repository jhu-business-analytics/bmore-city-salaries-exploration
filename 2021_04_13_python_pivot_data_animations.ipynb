# %% [markdown]
# <a href="https://colab.research.google.com/github/melanieshimano/bmore-city-salaries-exploration/blob/main/2021_04_13_python_pivot_data_animations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aggregating Data and Creating Data Animations with Plotly Express

# %% [markdown]
# ## import libraries

# %%
# for data analysis
import pandas as pd
import numpy as np

# for data viz
import plotly.express as px

# to download files
from google.colab import files

# %% [markdown]
# # import data

# %%
# csv with clean agency names
agency_data_url = "https://raw.githubusercontent.com/jhu-business-analytics/bmore-city-salaries-exploration/main/data-files/bmore_salaries_dept.csv"
df_dept = pd.read_csv(agency_data_url)

# %%
# preview data
df_dept.head()
# Out:
#    Unnamed: 0   id  firstname  ... overtime            fullname agencyname_only
# 0           0  201   DESIREE   ... -2912.42     DESIREE  ALSTON            HLTH
# 1           1  101     MAUDE   ... -3083.89        MAUDE  AKINS           TRANS
# 2           2  301  SHAVONNA   ...  -237.60  SHAVONNA  ANDERSON          POLICE
# 3           3   51  MARGARET   ... -3504.39     MARGARET  ADAMS            HLTH
# 4           4    1  PATRICIA   ... -5339.06     PATRICIA  AARON             OED
#
# [5 rows x 15 columns]

# %% [markdown]
# # Pivot Tables in Python

# %%
# keep only fy 2020 items in df
df_dept2020 = df_dept[df_dept["fiscalyear"] == "FY2020"]

# %%
# preview df2020
df_dept2020.head()
# Out:
#         Unnamed: 0      id  ...               fullname          agencyname_only
# 137200      137200  137451  ...      BEVERLY  ABDULLAH  HOUSING & COMMUNITY DEV
# 137201      137201  137452  ...      BEVERLY  ABDULLAH                   DEM 01
# 137202      137202  137453  ...      SHARON  ABDULLAHI          FIRE DEPARTMENT
# 137203      137203  137454  ...  MUHAMMED  ABDULLATEEF         GENERAL SERVICES
# 137204      137204  137455  ...   MUSTAFA  ABDULRAHMAN                   POLICE
#
# [5 rows x 15 columns]

# %%
# double check that fy is only 2020
df_dept2020["fiscalyear"].nunique()
# Out:
# 1

# %%
# make pivot table to look at avg annual salary in 2020 by department

df_2020_pivot_salary = pd.pivot_table(df_dept2020,
                                      index = "agencyname_only",
                                      values = "annualsalary",
                                      aggfunc = np.mean).reset_index()

# %%
# preview pivot table with avg salaries
df_2020_pivot_salary.head(10)
# Out:
#              agencyname_only  annualsalary
# 0              CIRCUIT COURT  62783.156463
# 1               CITY COUNCIL  57245.776699
# 2  CIVIL RIGHTS & WAGE ENFOR  76718.833333
# 3                       COMP  71393.698925
# 4           COUNCIL SERVICES  88638.666667
# 5                     DEM 01      0.000000
# 6                        DPW  48167.192087
# 7                  ELECTIONS  12913.428571
# 8   ENOCH PRATT FREE LIBRARY  45624.203448
# 9              ERS/EOS ADMIN  73356.297297

# %% [markdown]
# ## pivot table with text

# %%
# create a pivot table to look at job progression throught fiscal years

df_jobs = pd.pivot_table(df_dept,
                         index = "fullname",
                         columns = "fiscalyear",
                         values = "jobtitle",
                         aggfunc = np.sum).reset_index()

# %%
# preview pivot table
df_jobs.tail(20)
# Out:
# fiscalyear                 fullname  ...                   FY2020
# 36928                    ZOE  LEWIS  ...                      NaN
# 36929                   ZOE  MARTIN  ...                      NaN
# 36930                   ZOE  MICHAL  ...     OPERATIONS OFFICER I
# 36931                    ZOE MILLER  ...                      NaN
# 36932                  ZOE PFLIEGER  ...                      NaN
# 36933                   ZOE WALTERS  ...   OPERATIONS OFFICER III
# 36934               ZOELIA  LEACOCK  ...     EMERGENCY DISPATCHER
# 36935                     ZORA  LEE  ...  ELECTION JUDGES REGULAR
# 36936              ZSATEASE  TUCKER  ...  ELECTION JUDGES REGULAR
# 36937            ZULEYKA  RODRIGUEZ  ...                      NaN
# 36938             ZWENA  KILLIKELLY  ...           COMMUNITY AIDE
# 36939                ZYAIJAH  CLARK  ...                      NaN
# 36940               ZYAIRE  COLEMAN  ...                      NaN
# 36941              ZYCIAH  MARSHALL  ...           COMMUNITY AIDE
# 36942            ZYIONNA  MCKINSTRY  ...                      NaN
# 36943                ZYKIRA  DARDEN  ...           COMMUNITY AIDE
# 36944                 ZYLAN  WILKES  ...                      NaN
# 36945                   ZYLIL LLOYD  ...                      NaN
# 36946       ZYNEEYA  MARSHALL BAKER  ...                      NaN
# 36947              ZYREN  HARTGROVE  ...                      NaN
#
# [20 rows x 11 columns]

# %% [markdown]
# # Pandas Groupby

# %%
# get average salary for each agency by fiscal year
df_dept_fy_salary = df_dept.groupby(["fiscalyear", "agencyname_only"])["annualsalary"].agg(["mean"]).reset_index()

# %%
# preview data
df_dept_fy_salary.head()
# Out:
#   fiscalyear      agencyname_only          mean
# 0     FY2011        CIRCUIT COURT  53425.342857
# 1     FY2011         CITY COUNCIL  45527.602273
# 2     FY2011  COMMUNITY RELATIONS  52630.400000
# 3     FY2011                 COMP  53251.978022
# 4     FY2011     COUNCIL SERVICES  71730.000000

# %%
# preview original dataframe
df_dept.head()
# Out:
#    Unnamed: 0   id  firstname  ... overtime            fullname agencyname_only
# 0           0  201   DESIREE   ... -2912.42     DESIREE  ALSTON            HLTH
# 1           1  101     MAUDE   ... -3083.89        MAUDE  AKINS           TRANS
# 2           2  301  SHAVONNA   ...  -237.60  SHAVONNA  ANDERSON          POLICE
# 3           3   51  MARGARET   ... -3504.39     MARGARET  ADAMS            HLTH
# 4           4    1  PATRICIA   ... -5339.06     PATRICIA  AARON             OED
#
# [5 rows x 15 columns]

# %%
# get average salary, average gross pay, number of employees  for each agency by fiscal year
df_dept_fy_salary = df_dept.groupby(["fiscalyear", "agencyname_only"]).agg({"annualsalary": "mean",
                                                                            "grosspay": "mean",
                                                                            "id": "count"}).reset_index()

# %%
# preview new agg table
df_dept_fy_salary.head()
# Out:
#   fiscalyear      agencyname_only  annualsalary      grosspay   id
# 0     FY2011        CIRCUIT COURT  53425.342857  45404.091688  154
# 1     FY2011         CITY COUNCIL  45527.602273  33302.633068   88
# 2     FY2011  COMMUNITY RELATIONS  52630.400000  43192.792000   10
# 3     FY2011                 COMP  53251.978022  44668.891429   91
# 4     FY2011     COUNCIL SERVICES  71730.000000  64372.718000    5

# %% [markdown]
# # Line Graphs with Plotly Express

# %%
# make a line graph to show average gross pay over all fy
all_agency_line = px.line(df_dept_fy_salary,
                          x = "fiscalyear",
                          y = "grosspay",
                          color = "agencyname_only",
                          title = "Average Gross Pay for Baltimore City Government, FY2011-FY2020")

# %%
# show the graph
all_agency_line
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2a66c9f2-3008-4b88-bdfe-4be7ed4b1d1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2a66c9f2-3008-4b88-bdfe-4be7ed4b1d1e")) {
#                     Plotly.newPlot(
#                         '2a66c9f2-3008-4b88-bdfe-4be7ed4b1d1e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=CIRCUIT COURT<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=CIRCUIT COURT", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=CIRCUIT COURT", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [45404.09168831171, 49786.74503355705, 49679.454892086345, 49503.09092857145, 53901.54368794328, 52185.8254074074, 55069.6738582677, 58028.235037594015, 59271.995655737686, 55871.02115646257], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=CITY COUNCIL<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=CITY COUNCIL", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=CITY COUNCIL", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [33302.63306818181, 35781.19966666668, 40076.68965517243, 39169.29118279571, 39783.76569892473, 45585.54044444443, 44465.98614457832, 49456.57923076926, 47406.12986301371, 44289.528737864086], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COMMUNITY RELATIONS<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=COMMUNITY RELATIONS", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=COMMUNITY RELATIONS", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012"], "xaxis": "x", "y": [43192.792, 50764.60333333333], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COMP<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=COMP", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=COMP", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [44668.89142857144, 53513.13511627908, 49929.709684210546, 51840.53533333334, 56030.17384615384, 55485.71931034483, 55332.309684210486, 63872.42500000001, 62068.043647058825, 67540.99376344087], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COUNCIL SERVICES<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=COUNCIL SERVICES", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=COUNCIL SERVICES", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [64372.71799999999, 63727.98499999999, 73937.28, 73183.126, 64755.25, 76020.235, 85519.546, 71731.38166666667, 86554.15166666667, 90349.565], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=DPW<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=DPW", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=DPW", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [35715.693501697846, 40638.88829394068, 41095.04015040822, 42742.11776017132, 45371.746919471705, 44156.28907115466, 46138.69497140345, 50931.94775899435, 50898.96782647197, 51226.37276041657], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=ELECTIONS<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=ELECTIONS", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=ELECTIONS", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x",  ...

# %% [markdown]
# ## filter data to look at top 20 gross salaries in 2020

# %%
# filter to look at only fy 2020
df_fy_2020_agg = df_dept_fy_salary[df_dept_fy_salary["fiscalyear"] == "FY2020"]

# %%
df_fy_2020_agg.head()
# Out:
#     fiscalyear            agencyname_only  annualsalary      grosspay   id
# 341     FY2020              CIRCUIT COURT  62783.156463  55871.021156  147
# 342     FY2020               CITY COUNCIL  57245.776699  44289.528738  103
# 343     FY2020  CIVIL RIGHTS & WAGE ENFOR  76718.833333  64555.946250   24
# 344     FY2020                       COMP  71393.698925  67540.993763   93
# 345     FY2020           COUNCIL SERVICES  88638.666667  90349.565000    6

# %%
# sort by gross pay greatest to least
df_fy_2020_agg = df_fy_2020_agg.sort_values(by = "grosspay", ascending = False)

# %%
# preview top 20
df_top20gross = df_fy_2020_agg.head(20)

# %%
df_top20gross
# Out:
#     fiscalyear            agencyname_only  annualsalary      grosspay    id
# 373     FY2020                     POLICE  78346.381395  91635.065786  3225
# 367     FY2020      MO LABOR COMMISSIONER  91008.166667  90501.161667     6
# 345     FY2020           COUNCIL SERVICES  88638.666667  90349.565000     6
# 352     FY2020            FIRE DEPARTMENT  72811.170691  85064.767249  1781
# 359     FY2020      LEGISLATIVE REFERENCE  84940.833333  84840.463333     6
# 358     FY2020             LAW DEPARTMENT  89940.285714  79163.124454   119
# 353     FY2020                  FPR ADMIN  76403.464286  73162.608571    28
# 344     FY2020                       COMP  71393.698925  67540.993763    93
# 357     FY2020                         HR  77870.421053  65755.059079    76
# 372     FY2020        PLANNING DEPARTMENT  70646.900000  65294.269167    60
# 376     FY2020           SHERIFF'S OFFICE  59637.829146  65101.239749   199
# 343     FY2020  CIVIL RIGHTS & WAGE ENFOR  76718.833333  64555.946250    24
# 350     FY2020              ERS/EOS ADMIN  73356.297297  64537.650541    37
# 378     FY2020    STATES ATTORNEYS OFFICE  70809.411765  62429.570973   442
# 366     FY2020         MO INFO TECHNOLOGY  73791.902256  62409.357068   133
# 361     FY2020             MAYOR'S OFFICE  77624.402367  56778.091302   169
# 356     FY2020    HOUSING & COMMUNITY DEV  61101.242630  56034.067642   441
# 341     FY2020              CIRCUIT COURT  62783.156463  55871.021156   147
# 351     FY2020                        FIN  62149.415282  55738.395249   301
# 354     FY2020           GENERAL SERVICES  52689.745679  53718.774049   405

# %%
# create a list of top 20 agencies
top20_list = df_top20gross["agencyname_only"].tolist()

# %%
# filter full dat with top 20 agencies
df_dept_fy_salary_top20 = df_dept_fy_salary[df_dept_fy_salary["agencyname_only"].isin(top20_list)]

# %%
# preview filtered data
df_dept_fy_salary_top20.tail()
# Out:
#     fiscalyear          agencyname_only  annualsalary      grosspay    id
# 367     FY2020    MO LABOR COMMISSIONER  91008.166667  90501.161667     6
# 372     FY2020      PLANNING DEPARTMENT  70646.900000  65294.269167    60
# 373     FY2020                   POLICE  78346.381395  91635.065786  3225
# 376     FY2020         SHERIFF'S OFFICE  59637.829146  65101.239749   199
# 378     FY2020  STATES ATTORNEYS OFFICE  70809.411765  62429.570973   442

# %%
# make a line graph to show average gross pay over all fy for only top 20 gross in fy2020
top20_all_agency_line = px.line(df_dept_fy_salary_top20,
                          x = "fiscalyear",
                          y = "grosspay",
                          color = "agencyname_only",
                          title = "Average Gross Pay for Baltimore City Government, FY2011-FY2020")

# %%
# view the line graph
top20_all_agency_line
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="487db8ce-c551-4b15-886e-a323325d3fd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("487db8ce-c551-4b15-886e-a323325d3fd1")) {
#                     Plotly.newPlot(
#                         '487db8ce-c551-4b15-886e-a323325d3fd1',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=CIRCUIT COURT<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=CIRCUIT COURT", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=CIRCUIT COURT", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [45404.09168831171, 49786.74503355705, 49679.454892086345, 49503.09092857145, 53901.54368794328, 52185.8254074074, 55069.6738582677, 58028.235037594015, 59271.995655737686, 55871.02115646257], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COMP<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=COMP", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=COMP", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [44668.89142857144, 53513.13511627908, 49929.709684210546, 51840.53533333334, 56030.17384615384, 55485.71931034483, 55332.309684210486, 63872.42500000001, 62068.043647058825, 67540.99376344087], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COUNCIL SERVICES<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=COUNCIL SERVICES", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=COUNCIL SERVICES", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [64372.71799999999, 63727.98499999999, 73937.28, 73183.126, 64755.25, 76020.235, 85519.546, 71731.38166666667, 86554.15166666667, 90349.565], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=ERS/EOS ADMIN<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=ERS/EOS ADMIN", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=ERS/EOS ADMIN", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [45334.0374074074, 45610.673571428575, 45185.64034482759, 54310.91931034482, 54926.249062500014, 56004.83516129033, 53427.228620689646, 61479.657096774215, 57833.91699999999, 64537.65054054053], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FIN<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=FIN", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=FIN", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [40066.59241509433, 44014.82199288253, 45603.60921985817, 46771.525174825176, 48982.798996539794, 51428.89323741007, 51112.09867924526, 55393.58563176894, 56798.73338582679, 55738.39524916946], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FIRE DEPARTMENT<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=FIRE DEPARTMENT", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "agencyname_only=FIRE DEPARTMENT", "showlegend": true, "type": "scatter", "x": ["FY2011", "FY2012", "FY2013", "FY2014", "FY2015", "FY2016", "FY2017", "FY2018", "FY2019", "FY2020"], "xaxis": "x", "y": [61191.63681044964, 65716.7555317919, 69321.29625, 76866.90991116737, 77826.62785006192, 74793.79215845294, 78951.10093389924, 80497.36889940832, 82595.62093452374, 85064.76724873675], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FPR ADMIN<br>fiscalyear=%{x}<br>grosspay=%{y}", "legendgroup": "agencyname_only=FPR ADMIN", "line": {"color": "#FF6692", "dash" ...

# %% [markdown]
# # Make an Bubble Chart animation with Plotly Express

# %%
# preview top 20 agencies
df_dept_fy_salary_top20.head()
# Out:
#   fiscalyear   agencyname_only  annualsalary      grosspay   id
# 0     FY2011     CIRCUIT COURT  53425.342857  45404.091688  154
# 3     FY2011              COMP  53251.978022  44668.891429   91
# 4     FY2011  COUNCIL SERVICES  71730.000000  64372.718000    5
# 8     FY2011     ERS/EOS ADMIN  53512.703704  45334.037407   27
# 9     FY2011               FIN  47092.222642  40066.592415  265

# %%
# make animation with all parameters that we have
top20_all_agency_animation = px.scatter(df_dept_fy_salary_top20,
                          x = "annualsalary",
                          y = "grosspay",
                          color = "agencyname_only",
                          size = "id",
                          animation_frame = "fiscalyear",
                          title = "Average Gross Pay vs Annual Salary for Baltimore City Government, FY2011-FY2020",
                          range_x = [30000, 100000],
                          range_y = [30000, 100000])

# %%
# show animation
top20_all_agency_animation
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1ff0fa86-c88b-437b-994a-7e761d643cca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1ff0fa86-c88b-437b-994a-7e761d643cca")) {
#                     Plotly.newPlot(
#                         '1ff0fa86-c88b-437b-994a-7e761d643cca',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=CIRCUIT COURT<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=CIRCUIT COURT", "marker": {"color": "#636efa", "size": [154], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=CIRCUIT COURT", "showlegend": true, "type": "scatter", "x": [53425.34285714286], "xaxis": "x", "y": [45404.09168831171], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COMP<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=COMP", "marker": {"color": "#EF553B", "size": [91], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=COMP", "showlegend": true, "type": "scatter", "x": [53251.97802197802], "xaxis": "x", "y": [44668.89142857144], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=COUNCIL SERVICES<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=COUNCIL SERVICES", "marker": {"color": "#00cc96", "size": [5], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=COUNCIL SERVICES", "showlegend": true, "type": "scatter", "x": [71730.0], "xaxis": "x", "y": [64372.71799999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=ERS/EOS ADMIN<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=ERS/EOS ADMIN", "marker": {"color": "#ab63fa", "size": [27], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=ERS/EOS ADMIN", "showlegend": true, "type": "scatter", "x": [53512.7037037037], "xaxis": "x", "y": [45334.0374074074], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FIN<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=FIN", "marker": {"color": "#FFA15A", "size": [265], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=FIN", "showlegend": true, "type": "scatter", "x": [47092.222641509434], "xaxis": "x", "y": [40066.59241509433], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FIRE DEPARTMENT<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=FIRE DEPARTMENT", "marker": {"color": "#19d3f3", "size": [1646], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=FIRE DEPARTMENT", "showlegend": true, "type": "scatter", "x": [59711.76974483597], "xaxis": "x", "y": [61191.63681044964], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=FPR ADMIN<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=FPR ADMIN", "marker": {"color": "#FF6692", "size": [21], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=FPR ADMIN", "showlegend": true, "type": "scatter", "x": [55132.380952380954], "xaxis": "x", "y": [48562.873809523815], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "agencyname_only=GENERAL SERVICES<br>fiscalyear=FY2011<br>annualsalary=%{x}<br>grosspay=%{y}<br>id=%{marker.size}", "legendgroup": "agencyname_only=GENERAL SERVICES", "marker": {"color": "#B6E880", "size": [396], "sizemode": "area", "sizeref": 8.6875, "symbol": "circle"}, "mode": "markers", "name": "agencyname_only=GENERAL SERVICES", "showlegend": true, "type": "scatter", "x": [43526.545454545456], "xaxis": "x", "y": [40579.269040404004], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplat ...
